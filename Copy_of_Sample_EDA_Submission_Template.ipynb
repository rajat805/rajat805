# %% [markdown]
# <a href="https://colab.research.google.com/github/rajat805/rajat805/blob/main/Copy_of_Sample_EDA_Submission_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -Factors Influencing Automobile Pricing: An Exploratory Data Analysis of Vehicle Specifications

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual/Team
# ##### **Team Member 1 -

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/rajat805

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The automobile market consists of thousands of vehicles with different specifications, including engine size, horsepower, fuel type, transmission, seating capacity, and body style. Understanding which factors significantly influence the price of a vehicle is important for manufacturers, dealers, and customers. The objective of this project is to analyze automobile data to identify the major factors affecting car prices and provide business insights that can help optimize pricing strategies and improve decision-making.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Business Objective
#
# The primary business objective of this project is to identify and analyze the key factors that influence automobile pricing in the market. By performing exploratory data analysis on vehicle specifications such as manufacturer, engine size, horsepower, fuel type, transmission type, body style, and seating capacity, this project aims to understand the relationship between these features and vehicle prices.
#
# The insights obtained from this analysis can help automobile manufacturers optimize pricing strategies, understand market trends, identify high-value vehicle segments, and make informed business decisions. Additionally, the findings can assist customers and dealers in evaluating the factors that contribute to the cost of a vehicle and support data-driven decision-making in the automotive industry.Answer Here.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Data manipulation
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# System libraries
import warnings
warnings.filterwarnings('ignore')

# Display settings
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# Plot settings
plt.rcParams['figure.figsize'] = (10,6)

print("Libraries imported successfully.")
# Out:
# Libraries imported successfully.

# %% [markdown]
# ### Dataset Loading

# %%
# Load Datase
df= pd.read_csv("/content/v1-legacy-carapi-datafeed-sample.csv")
display(df.head())
# Out:
#    Make Id Make Name  Model Id Model Name  Trim Id  Trim Year  \
# 0        1     Acura        97        ILX     6292       2020
# 1        1     Acura        97        ILX     6295       2020
# 2        1     Acura        97        ILX     6293       2020
# 3        1     Acura        97        ILX     6296       2020
# 4        1     Acura        97        ILX     6294       2020
#
#                         Trim Name  \
# 0                            Base
# 1     Premium and A-SPEC Packages
# 2                 Premium Package
# 3  Technology and A-SPEC Packages
# 4              Technology Package
#
#                                     Trim Description  Trim Msrp  Trim Invoice  \
# 0                          4dr Sedan (2.4L 4cyl 8AM)      25900       24617.0
# 1  Premium and A-SPEC Packages 4dr Sedan (2.4L 4c...      29750       28264.0
# 2          Premium Package 4dr Sedan (2.4L 4cyl 8AM)      27750       26370.0
# ...

# %% [markdown]
# ### Dataset First View

# %%
# Display first 10 rows
df.head(10)
# Out:
#    Make Id Make Name  Model Id Model Name  Trim Id  Trim Year  \
# 0        1     Acura        97        ILX     6292       2020
# 1        1     Acura        97        ILX     6295       2020
# 2        1     Acura        97        ILX     6293       2020
# 3        1     Acura        97        ILX     6296       2020
# 4        1     Acura        97        ILX     6294       2020
# 5        1     Acura         2        MDX     6297       2020
# 6        1     Acura         2        MDX     6298       2020
# 7        1     Acura         2        MDX     6299       2020
# 8        1     Acura         2        MDX     6301       2020
# 9        1     Acura         2        MDX     6302       2020
#
#                         Trim Name  \
# 0                            Base
# 1     Premium and A-SPEC Packages
# 2                 Premium Package
# 3  Technology and A-SPEC Packages
# 4              Technology Package
# 5                            Base
# 6                            Base
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
# Dataset Rows & Columns Count

print("Number of Rows :", df.shape[0])
print("Number of Columns :", df.shape[1])
# Out:
# Number of Rows : 17707
# Number of Columns : 57

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Information

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17707 entries, 0 to 17706
# Data columns (total 57 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Make Id                                      17707 non-null  int64
#  1   Make Name                                    17707 non-null  object
#  2   Model Id                                     17707 non-null  int64
#  3   Model Name                                   17707 non-null  object
#  4   Trim Id                                      17707 non-null  int64
#  5   Trim Year                                    17707 non-null  int64
#  6   Trim Name                                    17707 non-null  object
#  7   Trim Description                             17707 non-null  object
#  8   Trim Msrp                                    17707 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
# Display duplicate rows

df[df.duplicated()]
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
missing_values = df.isnull().sum()

# Display columns having missing values
missing_values = missing_values[missing_values > 0]

print(missing_values)
# Out:
# Trim Invoice                                       3
# Engine Id                                         34
# Engine Type                                       34
# Engine Fuel Type                                  34
# Engine Cylinders                                 255
# Engine Size                                      255
# Engine Horsepower Hp                             176
# Engine Horsepower Rpm                            560
# Engine Torque Ft Lbs                             515
# Engine Torque Rpm                                834
# Engine Valves                                    258
# Engine Valve Timing                             1361
# Engine Cam Type                                  258
# Engine Drive Type                                 34
# Engine Transmission                               34
# Body Seats                                        34
# Body Length                                      145
# Body Width                                       913
# ...

# %%
# Visualizing Missing Values

# Missing Values Count
missing = df.isnull().sum()
missing = missing[missing > 0].sort_values(ascending=False)

plt.figure(figsize=(14,6))

missing.plot(kind='bar')

plt.title('Missing Values Count by Feature')
plt.xlabel('Features')
plt.ylabel('Number of Missing Values')
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# # Visualizing the Missing Values
#
# A visualization of missing values was created to understand the distribution and concentration of null values across different features in the dataset. The heatmap and bar chart provide a clear representation of which variables contain missing observations and the extent of missing data.
#
# From the visualization, it can be observed that some features contain a significant number of missing values, while others have complete information. Identifying missing data patterns is an important step in the data preprocessing phase because missing values can affect the accuracy and reliability of the analysis.
#
# Understanding the distribution of missing values helps in selecting appropriate data cleaning techniques, such as removing irrelevant features, imputing missing values, or applying advanced preprocessing methods to ensure the quality of the analysis and improve the reliability of business insights.

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset contains 17,707 rows and 57 columns, indicating a large collection of automobile records with multiple features.
# The dataset consists of both numerical and categorical variables. Numerical variables include engine size, horsepower, mileage, and price, while categorical variables include manufacturer name, fuel type, transmission type, and body style.
# The dataset contains detailed information related to automobiles, such as manufacturer details, model information, engine specifications, transmission details, fuel type, body characteristics, mileage, and pricing information.
# Some features contain missing values, particularly in columns related to electric vehicle specifications, mileage, and certain technical attributes. Proper data cleaning and preprocessing will be required before analysis.
# Duplicate values were checked to ensure data quality and avoid biased results during analysis.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns

print("Total Columns:", len(df.columns))
print("\nDataset Columns:\n")

for col in df.columns:
    print(col)
# Out:
# Total Columns: 57
#
# Dataset Columns:
#
# Make Id
# Make Name
# Model Id
# Model Name
# Trim Id
# Trim Year
# Trim Name
# Trim Description
# Trim Msrp
# Trim Invoice
# Trim Created
# Trim Modified
# Engine Id
# Engine Type
# Engine Fuel Type
# Engine Cylinders
# Engine Size
# Engine Horsepower Hp
# Engine Horsepower Rpm
# Engine Torque Ft Lbs
# Engine Torque Rpm
# Engine Valves
# Engine Valve Timing
# Engine Cam Type
# Engine Drive Type
# Engine Transmission
# Body Id
# Body Type
# Body Doors
# Body Seats
# Body Length
# Body Width
# Body Height
# Body Wheel Base
# Body Front Track
# Body Rear Track
# Body Ground Clearance
# Body Cargo Capacity
# Body Max Cargo Capacity
# Body Curb Weight
# Body Gross Weight
# Body Max Payload
# Body Max Towing Capacity
# Mileage Id
# Mileage Fuel Tank Capacity
# Mileage Combined Mpg
# Mileage Epa City Mpg
# Mileage Epa Highway Mpg
# Mileage Range City
# Mileage Range Highway
# Mileage Epa Combined Mpg Electric
# Mileage Epa City Mpg Electric
# ...

# %% [markdown]
# # Dataset Columns
#
# The dataset contains a total of 57 variables describing different aspects of automobiles. These variables include information related to manufacturer details, model specifications, engine characteristics, fuel type, transmission system, body dimensions, mileage information, and pricing attributes.
#
# The features can broadly be classified into the following categories:
#
# * Manufacturer Information
# * Model Information
# * Engine Specifications
# * Transmission Details
# * Body Characteristics
# * Mileage Information
# * Electric Vehicle Specifications
# * Pricing Information
#
# Understanding the available variables helps identify the relevant features required for analyzing the factors influencing automobile prices.

# %%
# Dataset Describe

df.describe()
# Out:
#             Make Id      Model Id        Trim Id     Trim Year     Trim Msrp  \
# count  17707.000000  17707.000000   17707.000000  17707.000000  1.770700e+04
# mean      20.042413    275.892133   15329.854916   2017.514655  4.854835e+04
# std       12.748010    209.868165    6538.017344      1.694286  4.408983e+04
# min        1.000000      2.000000    6292.000000   2015.000000  0.000000e+00
# 25%        8.000000    167.000000   10718.500000   2016.000000  3.048000e+04
# 50%       19.000000    267.000000   15145.000000   2018.000000  3.933500e+04
# 75%       29.000000    379.000000   19572.500000   2019.000000  5.104500e+04
# max       56.000000   5024.000000  101978.000000   2020.000000  1.990064e+06
#
#         Trim Invoice     Engine Id   Engine Size  Engine Horsepower Hp  \
# count   17704.000000  17673.000000  17452.000000          17531.000000
# mean    39881.853479  15159.662197      3.481423            291.791113
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# # Variables Description
#
# The dataset contains various features related to automobile manufacturers, engine specifications, vehicle body characteristics, fuel efficiency, transmission systems, and pricing information. For the purpose of this project, the variables that are directly related to automobile pricing analysis have been selected.
#
# The target variable for this analysis is **Trim MSRP**, which represents the Manufacturer's Suggested Retail Price (MSRP) of a vehicle. Independent variables such as manufacturer name, engine size, horsepower, fuel type, transmission type, body type, seating capacity, and mileage specifications will be analyzed to understand their impact on vehicle pricing.
#
# These variables provide valuable insights into the technical and market characteristics of automobiles and will help identify the major factors influencing automobile prices.

# %% [markdown]
# Answer Here

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
# Create a dataframe of unique values

unique_values = pd.DataFrame({
    'Variable': df.columns,
    'Unique Values Count': [df[col].nunique() for col in df.columns]
})

unique_values.sort_values(by='Unique Values Count', ascending=False)
# Out:
#                                        Variable  Unique Values Count
# 4                                       Trim Id                17707
# 26                                      Body Id                17707
# 12                                    Engine Id                17673
# 43                                   Mileage Id                17673
# 9                                  Trim Invoice                12386
# 8                                     Trim Msrp                 7199
# 7                              Trim Description                 6809
# 39                             Body Curb Weight                 2512
# 6                                     Trim Name                 1809
# 41                             Body Max Payload                 1259
# 40                            Body Gross Weight                  665
# 2                                      Model Id                  551
# 3                                    Model Name                  549
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# ==========================================================
# DATA WRANGLING
# ==========================================================

# Create a copy of the original dataset
df_copy = df.copy()

# Display dataset shape before cleaning
print("Dataset Shape Before Cleaning:", df_copy.shape)

# ==========================================================
# Check duplicate values
# ==========================================================

duplicates = df_copy.duplicated().sum()
print("\nNumber of duplicate rows:", duplicates)

# Remove duplicate records
df_copy.drop_duplicates(inplace=True)

print("Dataset Shape After Removing Duplicates:",
      df_copy.shape)

# ==========================================================
# Check missing values
# ==========================================================

missing_values = df_copy.isnull().sum()
missing_values = missing_values[missing_values > 0]

print("\nColumns having missing values:")
print(missing_values)

# ==========================================================
# Calculate percentage of missing values
# ==========================================================

missing_percent = (
    df_copy.isnull().sum() /
    len(df_copy)
) * 100

missing_percent = missing_percent[
    missing_percent > 0
].sort_values(ascending=False)

print("\nPercentage of missing values:")
print(missing_percent)

# ==========================================================
# Drop columns having more than 70% missing values
# ==========================================================

threshold = 70

columns_to_drop = missing_percent[
    missing_percent > threshold
].index

print("\nColumns to drop:")
print(columns_to_drop)

df_copy.drop(
    columns=columns_to_drop,
    inplace=True
)

# ==========================================================
# Fill numerical missing values using median
# ==========================================================

numerical_cols = df_copy.select_dtypes(
    include=['int64','float64']
).columns

for col in numerical_cols:
    df_copy[col].fillna(
        df_copy[col].median(),
        inplace=True
    )

# ==========================================================
# Fill categorical missing values using mode
# ==========================================================

categorical_cols = df_copy.select_dtypes(
    include='object'
).columns

for col in categorical_cols:
    if df_copy[col].isnull().sum() > 0:
        df_copy[col].fillna(
            df_copy[col].mode()[0],
            inplace=True
        )

# ==========================================================
# Final check
# ==========================================================

print("\nRemaining Missing Values:")
print(df_copy.isnull().sum().sum())

print("\nFinal Dataset Shape:")
print(df_copy.shape)
# Out:
# Dataset Shape Before Cleaning: (17707, 57)
#
# Number of duplicate rows: 0
# Dataset Shape After Removing Duplicates: (17707, 57)
#
# Columns having missing values:
# Trim Invoice                                       3
# Engine Id                                         34
# Engine Type                                       34
# Engine Fuel Type                                  34
# Engine Cylinders                                 255
# Engine Size                                      255
# Engine Horsepower Hp                             176
# Engine Horsepower Rpm                            560
# Engine Torque Ft Lbs                             515
# Engine Torque Rpm                                834
# Engine Valves                                    258
# Engine Valve Timing                             1361
# Engine Cam Type                                  258
# Engine Drive Type                                 34
# Engine Transmission                               34
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# # What all manipulations have you done and insights you found?
#
# Several data wrangling and preprocessing techniques were applied to improve the quality and usability of the dataset before performing exploratory data analysis.
#
# ### Data Manipulations Performed
#
# 1. **Created a copy of the original dataset** to preserve the raw data and perform all operations on a separate working dataset.
#
# 2. **Checked for duplicate records** using the `duplicated()` function to identify redundant observations that could affect the analysis.
#
# 3. **Analyzed missing values** by calculating the count and percentage of null values present in each feature.
#
# 4. **Visualized missing values** to understand their distribution and identify features with a high percentage of missing observations.
#
# 5. **Removed or treated missing values** using appropriate techniques such as dropping irrelevant columns with excessive missing data and imputing remaining missing values using statistical methods.
#
# 6. **Examined data types** to ensure that each variable was stored in the correct format for analysis.
#
# 7. **Analyzed unique values** in each variable to understand the diversity and cardinality of the dataset.
#
# 8. **Identified important features** related to automobile pricing, including manufacturer, engine specifications, fuel type, transmission type, body characteristics, mileage, and price.
#
# ### Insights Found
#
# * The dataset contains a large number of automobile records with diverse manufacturers and vehicle categories.
# * Several features contain missing values, particularly those related to electric vehicle specifications.
# * The dataset includes both categorical and numerical variables, making it suitable for comprehensive exploratory data analysis.
# * Variables such as manufacturer, engine size, horsepower, fuel type, transmission type, and body type appear to have a significant impact on automobile pricing.
# * The dataset is sufficiently rich to identify pricing patterns, market segments, and business insights related to the automobile industry.
#
# The data wrangling process improved the quality of the dataset and prepared it for reliable and meaningful exploratory data analysis.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['Trim Msrp'], bins=40, kde=True)
plt.title('Distribution of Automobile Prices')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.A histogram was chosen because it is the most effective visualization for understanding the distribution of a continuous numerical variable such as automobile price. It helps identify the concentration of values, skewness, spread, and the presence of outliers in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# AnswThe distribution of automobile prices is highly right-skewed.
# Most vehicles fall within the lower and middle price ranges.
# A relatively small number of vehicles have extremely high prices, representing luxury and premium automobile segments.
# The presence of outliers indicates that the automobile market contains distinct pricing categories.er Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights obtained from this chart can create a positive business impact.
#
# Manufacturers can identify the most profitable market segments by understanding the price distribution.
# Companies can optimize their pricing strategies according to customer demand and market competition.
# The analysis shows that the majority of customers purchase vehicles in lower and medium price segments, which represent larger market opportunities.
#
# Potential negative growth may occur if manufacturers focus excessively on premium-priced vehicles, as the luxury segment represents a smaller portion of the overall market demand.

# %% [markdown]
# #### Chart - 2
#  Top 10 Automobile Manufacturers

# %%
# Chart - 2 visualization code

# %%
top_make = df['Make Name'].value_counts().head(10)

plt.figure(figsize=(10,6))
top_make.plot(kind='bar')
plt.title('Top 10 Automobile Manufacturers')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 3
# fuel Types Distribution

# %%
fuel = df['Engine Fuel Type'].value_counts().head(5)

plt.figure(figsize=(8,8))

plt.pie(
    fuel,
    labels=fuel.index,
    autopct='%1.1f%%'
)

plt.title('Fuel Type Distribution')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 4
# : Body Type Distribution

# %%
plt.figure(figsize=(10,6))
sns.countplot(
    y=df['Body Type'],
    order=df['Body Type'].value_counts().head(10).index
)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 5
# Horsepower Distribution

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df['Engine Horsepower Hp'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 6
# Engine Size vs Price

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(
    x='Engine Size',
    y='Trim Msrp',
    data=df.sample(3000)
)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 7
# Horsepower vs Price

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(
    x='Engine Horsepower Hp',
    y='Trim Msrp',
    data=df.sample(3000)
)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 8
# Fuel Type vs Price

# %%
plt.figure(figsize=(12,6))
sns.boxplot(
    x='Engine Fuel Type',
    y='Trim Msrp',
    data=df
)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 9
# Body Type vs Price

# %%
top_price = df.groupby('Make Name')['Trim Msrp']\
.mean().sort_values(ascending=False).head(10)

plt.figure(figsize=(10,6))
top_price.plot(kind='barh')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10
# Manufacturer vs Average Price

# %%
top_price = df.groupby('Make Name')['Trim Msrp']\
.mean().sort_values(ascending=False).head(10)

plt.figure(figsize=(10,6))
top_price.plot(kind='barh')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11

# %%
plt.figure(figsize=(12,8))

sns.heatmap(
    df.select_dtypes(include='number').corr(),
    cmap='coolwarm'
)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12
# Chart 12: Price vs Horsepower by Fuel Type
# Visualization Code

# %%
# Chart - 12 visualization code
plt.figure(figsize=(10,6))

sns.scatterplot(
    x='Engine Horsepower Hp',
    y='Trim Msrp',
    hue='Engine Fuel Type',
    data=df.sample(3000)
)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13
# : Price vs Engine Size by Body Type

# %%
# Chart - 13 visualization code
top_body = df['Body Type'].value_counts().head(6).index

plt.figure(figsize=(10,6))

sns.scatterplot(
    x='Engine Size',
    y='Trim Msrp',
    hue='Body Type',
    data=df[df['Body Type'].isin(top_body)].sample(3000)
)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization
plt.figure(figsize=(12,8))

sns.heatmap(
    df.select_dtypes(include='number').corr(),
    cmap='coolwarm'
)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
sns.pairplot(
    df[['Trim Msrp',
        'Engine Size',
        'Engine Horsepower Hp',
        'Engine Cylinders',
        'Mileage Combined Mpg']].dropna()
        .sample(1000)
)
plt.show()

# %%
sns.pairplot(df)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***

# %%
8882582016
